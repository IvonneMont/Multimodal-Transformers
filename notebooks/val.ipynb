# %%
import json
import glob
from utils.helpers import get_labels_and_frequencies
import shutil

# %%
data=[json.loads(l) for l in open("data_sets/proc/moviescope/test.jsonl")]

# %%
get_labels_and_frequencies("data_sets/proc/moviescope/test_old.jsonl")
# Out:
# (['Mystery',
#   'Thriller',
#   'Comedy',
#   'Romance',
#   'Drama',
#   'Fantasy',
#   'Horror',
#   'Sci-fi',
#   'Crime',
#   'Action',
#   'Family',
#   'Animation',
#   'Biography'],
#  Counter({'Mystery': 109,
#           'Thriller': 257,
#           'Comedy': 391,
#           'Romance': 215,
#           'Drama': 523,
#           'Fantasy': 168,
#           'Horror': 107,
#           'Sci-fi': 131,
#           'Crime': 186,
#           'Action': 216,
#           'Family': 107,
#           'Animation': 45,
#           'Biography': 60}))

# %%
get_labels_and_frequencies("data_sets/proc/moviescope/dev_old.jsonl")
# Out:
# (['Comedy',
#   'Fantasy',
#   'Drama',
#   'Romance',
#   'Sci-fi',
#   'Horror',
#   'Family',
#   'Animation',
#   'Thriller',
#   'Biography',
#   'Crime',
#   'Action',
#   'Mystery'],
#  Counter({'Comedy': 198,
#           'Fantasy': 85,
#           'Drama': 257,
#           'Romance': 118,
#           'Sci-fi': 56,
#           'Horror': 63,
#           'Family': 53,
#           'Animation': 22,
#           'Thriller': 138,
#           'Biography': 26,
#           'Crime': 89,
#           'Action': 102,
#           'Mystery': 45}))

# %%
# !mkdir data_sets/proc/moviescope/Posters_test

# %%
source="data_sets/proc/moviescope/MatchedPosters/"
destination="data_sets/proc/moviescope/Posters_test/"
for d in data:
    shutil.copyfile(source+str(d["id"])+".jpg",destination+str(d["id"])+".jpg")
    print(d['id'])
# Out:
# 1126
# 2511
# 1298
# 4476
# 2252
# 246
# 2303
# 4282
# 4247
# 3759
# 2013
# 3678
# 4755
# 815
# 1076
# 1140
# 3648
# 4452
# 2395
# 5006
# 1045
# 4433
# 4492
# 3591
# 2548
# 1685
# 4753
# 3230
# 2450
# 3717
# 605
# 787
# 3512
# 369
# 4387
# 868
# 4519
# 4255
# 1796
# 3768
# 2042
# 4996
# 127
# 1963
# 4145
# 4781
# 4348
# 4218
# 164
# 1152
# 2923
# 2455
# 3061
# 4825
# 2192
# 179
# 2183
# 3365
# 4123
# 757
# 1184
# 1293
# 3480
# 1130
# 1143
# 2386
# 3331
# 656
# 725
# 4359
# 1583
# 587
# 3559
# 523
# 2362
# 1005
# 4834
# 1503
# 4238
# 2993
# 1056
# 545
# 3650
# 960
# 1552
# 3214
# 1409
# 317
# 235
# 2587
# 3329
# 1208
# 1777
# 2518
# 3612
# 29
# 4842
# 3371
# 2361
# 4610
# 2124
# 1315
# 4240
# 3199
# 2244
# 1850
# 689
# 50
# 2422
# 1101
# 408
# 2879
# 2167
# 2253
# 4730
# 1471
# 2112
# 3207
# 1093
# 4898
# 165
# 1167
# 4091
# 2538
# 1522
# 729
# 3448
# 879
# 3270
# 4415
# 4762
# 2683
# 3303
# 1868
# 2512
# 1499
# 3297
# 2613
# 3388
# 1752
# 267
# 481
# 2397
# 1680
# 3432
# 2602
# 1403
# ...
